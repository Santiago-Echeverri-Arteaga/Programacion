# %% [markdown]
# # Forma, tipo e indexación
# Complete primero la tabla de predicciones en papel.

# %%
import numpy as np
datos = np.arange(20, dtype=float).reshape(4, 5)
datos

# %%
seleccion = datos[1:3, ::2]
print(seleccion.shape, seleccion.dtype)
seleccion

# %% [markdown]
# Explique qué observaciones conservaría la máscara `datos > 8` y qué forma tendrá la salida.
