# %% [markdown]
# # Script, módulo y notebook
# Ejecute las celdas fuera de orden una vez y explique por qué ese estado oculto dificulta la reproducibilidad. Luego reinicie el kernel y ejecute todo.

# %%
def energia_potencial(masa_kg, altura_m, gravedad=9.81):
    return masa_kg * gravedad * altura_m

# %%
masa = 2.0
altura = 3.0
energia_potencial(masa, altura)
